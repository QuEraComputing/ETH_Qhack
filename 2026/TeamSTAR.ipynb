# %% [markdown]
# # Part 1: Get comfortable using Tsim

# %% [markdown]
# # Part 2: Estimate STAR Fidelities

# %% [markdown]
# # Part 3 — Teleport a non-Clifford rotation into a logical qubit

# %% [markdown]
# # Part 4: Apply STAR in a larger algorithm
